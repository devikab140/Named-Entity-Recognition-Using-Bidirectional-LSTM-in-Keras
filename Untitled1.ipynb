# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.17.0
# GPU detected: []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 data = pd.read_csv("/content/drive/MyDrive/NER dataset.csv", encoding="latin1")
 data = data.fillna(method="ffill")
 data.head(20)
# Out:
# <ipython-input-9-dc4db2dcd920>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method="ffill")
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35177
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                          s["POS"].values.tolist(),
                                                          s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]

    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

sentences[0]
# Out:
# <ipython-input-14-d01bc099a84a>:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   self.grouped = self.data.groupby("Sentence #").apply(agg_func)
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

word2idx
# Out:
# {'Masahiko': 1,
#  'interest': 2,
#  'drug-smuggling': 3,
#  'Karbala': 4,
#  'Yasar': 5,
#  '5.63': 6,
#  'Kafeel': 7,
#  'harms': 8,
#  'Emmen': 9,
#  'avert': 10,
#  'alert': 11,
#  'soy': 12,
#  'earthenware': 13,
#  'Unity': 14,
#  'episode': 15,
#  'Poles': 16,
#  'Midwest': 17,
#  'Waxman': 18,
#  'crush': 19,
#  'Peters': 20,
#  'identification': 21,
#  'Petrodar': 22,
#  'Kane': 23,
#  'dropping': 24,
#  'Hard-liners': 25,
#  'foreign': 26,
#  'clampdown': 27,
#  'Athanase': 28,
#  'Sensex': 29,
#  'Bernama': 30,
#  'hunted': 31,
#  'Muthmahien': 32,
#  'Hao': 33,
#  'couple': 34,
#  'faulty': 35,
#  '1-to-1': 36,
#  'Freeman': 37,
#  'Charsadda': 38,
#  'Dhangadi': 39,
#  'Svinarov': 40,
#  'strolling': 41,
#  'explosion': 42,
#  'existed': 43,
#  'goo': 44,
#  'expenditures': 45,
#  'resurgent': 46,
#  'Yevpatoria': 47,
#  'safe': 48,
#  'instructed': 49,
#  'hide-outs': 50,
#  'Troedsson': 51,
#  'Holovaty': 52,
#  'forgo': 53,
#  'Is': 54,
#  'Kira': 55,
#  'Lashkar-e-Toiba': 56,
#  'Ignace': 57,
#  'Cleric': 58,
#  'defected': 59,
#  'Sabeel': 60,
#  'else': 61,
#  'Bernardo': 62,
#  'Djibouti': 63,
#  'gyroscopes': 64,
#  'consequence': 65,
#  'Hebei': 66,
#  'toxins': 67,
#  'northeastern': 68,
#  'duck': 69,
#  'left-leaning': 70,
#  'blow': 71,
#  'tombs': 72,
#  'ears': 73,
#  'ingredient': 74,
#  'Afghan-coalition': 75,
#  'sect': 76,
#  'four-year': 77,
#  'bless': 78,
#  'retract': 79,
#  'Rafsanjani': 80,
#  'license': 81,
#  'anti-cocaine': 82,
#  'Closing': 83,
#  'changed': 84,
#  'ultranationalist': 85,
#  'Emmy': 86,
#  'doubtful': 87,
#  '4,000': 88,
#  'Yielding': 89,
#  'Argentina': 90,
#  'Hastings': 91,
#  'sequence': 92,
#  'broad-based': 93,
#  'CCAMLR': 94,
#  'strive': 95,
#  'upholding': 96,
#  'Llasa': 97,
#  'posh': 98,
#  'Drunken': 99,
#  '7,000': 100,
#  'quoted': 101,
#  'Nirvana': 102,
#  'citizen': 103,
#  'coded': 104,
#  'PSV': 105,
#  'Elfriede': 106,
#  'turbans': 107,
#  'runoffs': 108,
#  'Previously': 109,
#  'scooters': 110,
#  'Cachaito': 111,
#  'sects': 112,
#  'mid-February': 113,
#  'Jelinek': 114,
#  'logical': 115,
#  'installed': 116,
#  'builds': 117,
#  'encourage': 118,
#  'Druze': 119,
#  'Yankham': 120,
#  'Newman': 121,
#  '178': 122,
#  'Who': 123,
#  'punish': 124,
#  'natural': 125,
#  'non-Arab': 126,
#  'Bashar': 127,
#  'calendar': 128,
#  'Case-Shiller': 129,
#  'Slumping': 130,
#  'banker': 131,
#  'pro-secular': 132,
#  'fatality': 133,
#  'Anne-Marie': 134,
#  'waterworks': 135,
#  'manat': 136,
#  'poverty': 137,
#  'selfish': 138,
#  'flowed': 139,
#  'Liechtenstein': 140,
#  'Dump': 141,
#  'Maumoon': 142,
#  'wealthy': 143,
#  '13-point': 144,
#  'Climate': 145,
#  '57.25': 146,
#  'inhibits': 147,
#  '22': 148,
#  'ire': 149,
#  'zinc': 150,
#  'Boy': 151,
#  'Vy': 152,
#  'Entrance': 153,
#  'implementation': 154,
#  "d'Ivoire": 155,
#  'intend': 156,
#  'Shaath': 157,
#  'Yvelines': 158,
#  'exceptions': 159,
#  'two-year-old': 160,
#  'export-led': 161,
#  'snow': 162,
#  'shipping': 163,
#  'Entertainer': 164,
#  'Coe': 165,
#  'actor-comedian': 166,
#  'offense': 167,
#  'A-H1N1': 168,
#  'Thad': 169,
#  'Us': 170,
#  'object': 171,
#  'technically': 172,
#  'Akerson': 173,
#  'congratulating': 174,
#  'Liv-Grete': 175,
#  'minimal': 176,
#  'length': 177,
#  're-bidding': 178,
#  'cruelty': 179,
#  'arming': 180,
#  'vigil': 181,
#  'solider': 182,
#  'trains': 183,
#  'Downer': 184,
#  'Torrential': 185,
#  'jeep': 186,
#  'DOE': 187,
#  'avian': 188,
#  'worst-ever': 189,
#  'catches': 190,
#  'Celebrations': 191,
#  'pamphlets': 192,
#  'Manchester': 193,
#  'married': 194,
#  'gores': 195,
#  'Chitral': 196,
#  'intercourse': 197,
#  'Officers': 198,
#  'Didier': 199,
#  'everybody': 200,
#  'Jokhang': 201,
#  'Makhaya': 202,
#  'willing': 203,
#  'Perito': 204,
#  'booming': 205,
#  'Olo': 206,
#  'Beatification': 207,
#  'Alfonso': 208,
#  'Eidsvig': 209,
#  'exits': 210,
#  'Sir': 211,
#  'shy': 212,
#  'temples': 213,
#  'hostage-taker': 214,
#  'Aghazadeh': 215,
#  '184': 216,
#  'long-awaited': 217,
#  'appropriately': 218,
#  'Woody': 219,
#  'Slovakia': 220,
#  '3700': 221,
#  'Providencia': 222,
#  'looped': 223,
#  'Borges': 224,
#  'dwelling': 225,
#  'mired': 226,
#  'Anyone': 227,
#  'Principlists': 228,
#  'investigating': 229,
#  'Sergeant': 230,
#  'sub-prime': 231,
#  'immersed': 232,
#  'Zaire': 233,
#  'importing': 234,
#  'reserved': 235,
#  'Cairo-based': 236,
#  'missiles': 237,
#  'sank': 238,
#  '21-member': 239,
#  'Unfortunately': 240,
#  'Griffin': 241,
#  'granite': 242,
#  'Ridge': 243,
#  'Selim': 244,
#  'magnate': 245,
#  'Tanvir': 246,
#  'Characterized': 247,
#  'scrap': 248,
#  'Hoiberg': 249,
#  'foreign-backed': 250,
#  'score': 251,
#  'shores': 252,
#  'Elbaradei': 253,
#  "Yar'Adua": 254,
#  'returned': 255,
#  'ammunition': 256,
#  '11,500': 257,
#  'DOGS': 258,
#  'African-Union': 259,
#  'chimneys': 260,
#  'Shyster': 261,
#  'Torn': 262,
#  'timber': 263,
#  'Hour': 264,
#  'invite': 265,
#  'dialysis': 266,
#  'Bab': 267,
#  'Khmer': 268,
#  'loan': 269,
#  'Miranshah': 270,
#  'happiness': 271,
#  'Marlins': 272,
#  'Billionaire': 273,
#  '26-member': 274,
#  'Rewards': 275,
#  'worse': 276,
#  'Hama': 277,
#  'blue': 278,
#  'three-party': 279,
#  'Kansas': 280,
#  'grower': 281,
#  'bundled': 282,
#  'ambassador-at-large': 283,
#  'quarter-point': 284,
#  'WMD': 285,
#  'Ging': 286,
#  'SpaceShipOne': 287,
#  'Hallmark': 288,
#  'forecast': 289,
#  'Saint-Paul': 290,
#  'Shell': 291,
#  'competes': 292,
#  'en': 293,
#  'winner': 294,
#  'Hadithah': 295,
#  'Arshad': 296,
#  'origins': 297,
#  'Shuttle': 298,
#  '1030': 299,
#  'aircraft-maker': 300,
#  'Haqooq-i-Zan': 301,
#  'Serra': 302,
#  'encounters': 303,
#  'Monastery': 304,
#  'choice': 305,
#  'codefendants': 306,
#  'sweeps': 307,
#  'Diary': 308,
#  'Katyusha-type': 309,
#  'attracted': 310,
#  '35-year-old': 311,
#  'Siirt': 312,
#  'Ericq': 313,
#  'lag': 314,
#  'worker': 315,
#  'checkups': 316,
#  '147': 317,
#  'morale-boosting': 318,
#  'Barak': 319,
#  'fourth-quarter': 320,
#  'Smoky': 321,
#  'Flanders': 322,
#  '12-story': 323,
#  'exposed': 324,
#  'abound': 325,
#  'Societies': 326,
#  'Grant': 327,
#  'military-police': 328,
#  'al-Qaida-inspired': 329,
#  'dragging': 330,
#  'Caroline': 331,
#  'proportions': 332,
#  'Scholars': 333,
#  'ARISTIDE': 334,
#  'safely': 335,
#  'party-goers': 336,
#  'housing-loan': 337,
#  'cigarettes': 338,
#  '2,500': 339,
#  'grappling': 340,
#  'hypocrisy': 341,
#  'Al-Faisal': 342,
#  'Admiral': 343,
#  'Compact': 344,
#  '61-year-old': 345,
#  'twins': 346,
#  'hinting': 347,
#  'bribery': 348,
#  'insure': 349,
#  'Maghreb': 350,
#  '03-Feb': 351,
#  'high-grade': 352,
#  'Bager': 353,
#  'Astana': 354,
#  'second-in-command': 355,
#  'veiled': 356,
#  'Krasniqi': 357,
#  'Fellow': 358,
#  'guidelines': 359,
#  'interests': 360,
#  'FAO': 361,
#  'p.m.': 362,
#  'quarrel': 363,
#  'counterterrorism': 364,
#  'Investigators': 365,
#  'Yalcinkaya': 366,
#  'makeover': 367,
#  'Woo-suk': 368,
#  'agriculture': 369,
#  'Alam': 370,
#  'Novye': 371,
#  'irresponsibly': 372,
#  'pre-judging': 373,
#  'FY10': 374,
#  'Interreligious': 375,
#  'Laotian': 376,
#  'regulate': 377,
#  '26': 378,
#  'diet': 379,
#  'preview': 380,
#  'typically': 381,
#  '96.26': 382,
#  'wilderness': 383,
#  'crippling': 384,
#  'waits': 385,
#  'Puri': 386,
#  'Flu': 387,
#  'fairness': 388,
#  'pepper': 389,
#  'cake': 390,
#  'ulcers': 391,
#  'watchers': 392,
#  'narrates': 393,
#  'revolutionized': 394,
#  'manage': 395,
#  'ball-point': 396,
#  '12.3': 397,
#  'Kospi': 398,
#  'Naxalites': 399,
#  'limestone': 400,
#  'Fernandes': 401,
#  'integrity': 402,
#  'Seydou': 403,
#  'Tennis': 404,
#  '14-thousand': 405,
#  'swirled': 406,
#  'Bin-Laden': 407,
#  'TCDD': 408,
#  'Ibobi': 409,
#  'sworn-in': 410,
#  'son-in-law': 411,
#  'author': 412,
#  'specifies': 413,
#  'campaigner': 414,
#  'Soku': 415,
#  "al-U'Zayra": 416,
#  'discriminatory': 417,
#  'biked': 418,
#  'Jama': 419,
#  'Solecki': 420,
#  'chink': 421,
#  'MAS': 422,
#  'shuttle': 423,
#  'demonstrating': 424,
#  'Sacramento': 425,
#  'wines': 426,
#  'pontificate': 427,
#  'Dabous': 428,
#  'capability': 429,
#  'pornography': 430,
#  'Growth': 431,
#  '1828': 432,
#  '52nd': 433,
#  'BOA': 434,
#  'UTC': 435,
#  'retaliate': 436,
#  'prohibits': 437,
#  'Ericsson': 438,
#  'Biak': 439,
#  'Corby': 440,
#  'syndrome': 441,
#  'speech': 442,
#  'divorcing': 443,
#  'surprised': 444,
#  'outer': 445,
#  'relocating': 446,
#  'displacing': 447,
#  'Lakshman': 448,
#  'ICC': 449,
#  'tennis': 450,
#  'Skier': 451,
#  'prosperity': 452,
#  '45-day': 453,
#  'Dukeness': 454,
#  'mangos': 455,
#  'battled': 456,
#  'Contemporary': 457,
#  'Operatives': 458,
#  'demanding': 459,
#  'interivew': 460,
#  'repay': 461,
#  'Condominium': 462,
#  'Byrd': 463,
#  '59.4': 464,
#  'interwoven': 465,
#  'Wainganga': 466,
#  'Autonomy': 467,
#  'independents': 468,
#  'upsurge': 469,
#  'prophet': 470,
#  'Dale': 471,
#  'Haneef': 472,
#  'Jerzy': 473,
#  'seaport': 474,
#  'FLEA': 475,
#  'Minsk': 476,
#  'McBride': 477,
#  'Beilin': 478,
#  'destructive': 479,
#  'Pisanu': 480,
#  'gold': 481,
#  'reverberated': 482,
#  'Maksim': 483,
#  'Rita': 484,
#  'derive': 485,
#  'Cologne': 486,
#  'vanished': 487,
#  'warden': 488,
#  'follow': 489,
#  'approach': 490,
#  'commands': 491,
#  'Yake': 492,
#  '1932': 493,
#  'unifying': 494,
#  'bound': 495,
#  'Faisal': 496,
#  'cooled': 497,
#  'Number': 498,
#  'combined': 499,
#  'ligament': 500,
#  'Frente': 501,
#  'Breast': 502,
#  'demontrators': 503,
#  'drills': 504,
#  'suffocation': 505,
#  'Ramos-Horta': 506,
#  'reactors': 507,
#  'reminded': 508,
#  'zone': 509,
#  'Kampala': 510,
#  'ANSA': 511,
#  'anti-THAKSIN': 512,
#  'Anil': 513,
#  'lofty': 514,
#  'pay': 515,
#  'Purim': 516,
#  'screenings': 517,
#  'Non-Violent': 518,
#  '38-year-old': 519,
#  'Tachileik': 520,
#  'firms': 521,
#  'Ulema': 522,
#  'Fourth': 523,
#  '..': 524,
#  'devastating': 525,
#  'barcoded': 526,
#  'taking': 527,
#  'flagon': 528,
#  'Laisenia': 529,
#  'Beware': 530,
#  'reproached': 531,
#  'Norway-based': 532,
#  'Post-ABC': 533,
#  'Cholera': 534,
#  'Dan': 535,
#  'critics': 536,
#  'Megawatt': 537,
#  'accessories': 538,
#  'abundance': 539,
#  'intake': 540,
#  'condominiums': 541,
#  'bad': 542,
#  'Machage': 543,
#  'shadows': 544,
#  'enclaves': 545,
#  'pretended': 546,
#  'tacit': 547,
#  'Berezovsky': 548,
#  'Robitaille': 549,
#  'layoff': 550,
#  'Nashville': 551,
#  'Laith': 552,
#  'Sari': 553,
#  'showed': 554,
#  'FNL': 555,
#  '8000': 556,
#  'jumper': 557,
#  'Sidique': 558,
#  'corruption-free': 559,
#  'Descriptions': 560,
#  'humaneness': 561,
#  'nun': 562,
#  'al-Jazeera': 563,
#  'Patna': 564,
#  'denial-of-service': 565,
#  'compensate': 566,
#  'documents': 567,
#  'poses': 568,
#  'Riga': 569,
#  'Roswell': 570,
#  'Equus': 571,
#  'pharaohs': 572,
#  'Andrey': 573,
#  'swear-in': 574,
#  'Renen': 575,
#  'handling': 576,
#  'civilization': 577,
#  'Sarawan': 578,
#  'Attackers': 579,
#  'Osako': 580,
#  'Nuys': 581,
#  'overthrowing': 582,
#  '2,700': 583,
#  'Cancun': 584,
#  'persist': 585,
#  'Muthana': 586,
#  'Victims': 587,
#  'garlicky': 588,
#  'impassioned': 589,
#  'preventative': 590,
#  'exchanged': 591,
#  'Combat': 592,
#  'insurgency-related': 593,
#  'Sirleaf': 594,
#  'Sung-ho': 595,
#  'outdated': 596,
#  'Limited': 597,
#  '25-meter-long': 598,
#  'plaque': 599,
#  'preparatory': 600,
#  'Laghman': 601,
#  'Soaring': 602,
#  'Rosoboronexport': 603,
#  'War': 604,
#  'Kingdom': 605,
#  'MILOSEVIC': 606,
#  'aircraft': 607,
#  '23-25': 608,
#  'Winners': 609,
#  'Sandy': 610,
#  'Manx': 611,
#  'Boedihardjo': 612,
#  'near-poor': 613,
#  'Confirmation': 614,
#  'longtime': 615,
#  'Canyon': 616,
#  'recouped': 617,
#  'kingdoms': 618,
#  'Adolf': 619,
#  'salaries': 620,
#  'loads': 621,
#  'certain': 622,
#  'Boundary': 623,
#  'Palestine': 624,
#  'fractures': 625,
#  'denies': 626,
#  'worshippers': 627,
#  'possibly': 628,
#  '173': 629,
#  'wars': 630,
#  'hearing': 631,
#  'aboriginal': 632,
#  'Adjustment': 633,
#  'DUC': 634,
#  'Facing': 635,
#  'Stephens': 636,
#  'Ringwald': 637,
#  'thundershowers': 638,
#  'Goldman': 639,
#  'greats': 640,
#  'architectural': 641,
#  'Mindaoudou': 642,
#  'mayors': 643,
#  'Rak': 644,
#  'Pleasure': 645,
#  'iconic': 646,
#  'SIM': 647,
#  'Namibia': 648,
#  'insisted': 649,
#  'Wearing': 650,
#  'Hmawbi': 651,
#  '646': 652,
#  'Triumf': 653,
#  'insider': 654,
#  'respect': 655,
#  'anti-election': 656,
#  'campuses': 657,
#  'rigged': 658,
#  '21': 659,
#  'keeping': 660,
#  'degenerative': 661,
#  'clarify': 662,
#  'civilian': 663,
#  'respectable': 664,
#  'yelled': 665,
#  'maltreat': 666,
#  'deploying': 667,
#  'introduction': 668,
#  'collective': 669,
#  'al-Khaznawi': 670,
#  'hosting': 671,
#  'Code': 672,
#  'Ban': 673,
#  'sidestep': 674,
#  'pews': 675,
#  'imprudence': 676,
#  'Boer': 677,
#  'bird': 678,
#  'underscores': 679,
#  'batsmen': 680,
#  'belatedly': 681,
#  'Gaule': 682,
#  'Embassy': 683,
#  'Rugged': 684,
#  'overwhelmingly': 685,
#  'applications': 686,
#  'trumpets': 687,
#  'oil-producing': 688,
#  'Helena': 689,
#  'soils': 690,
#  'Belbin': 691,
#  'super-combi': 692,
#  'Carbon': 693,
#  'hangar': 694,
#  'convicts': 695,
#  'waste': 696,
#  'waded': 697,
#  'CARE': 698,
#  'featuring': 699,
#  'Europeans': 700,
#  'Atomic': 701,
#  'Ibom': 702,
#  'Belgians': 703,
#  'Soviet-imposed': 704,
#  'expenses': 705,
#  'discontinued': 706,
#  'army-led': 707,
#  'you': 708,
#  'massing': 709,
#  '02-Jun': 710,
#  'rider': 711,
#  'Imphal': 712,
#  'Bogota': 713,
#  'all-inclusive': 714,
#  'persecuting': 715,
#  'Treasure': 716,
#  'affair': 717,
#  'Idrissu': 718,
#  'Legal': 719,
#  'veto-wielding': 720,
#  '1452': 721,
#  'effective': 722,
#  'them': 723,
#  'onlookers': 724,
#  'jailing': 725,
#  'Hemispheric': 726,
#  'crescent': 727,
#  'Massaua': 728,
#  'sorts': 729,
#  'Serpent': 730,
#  'Rae': 731,
#  'start': 732,
#  'Odense': 733,
#  'pose': 734,
#  'some': 735,
#  'uses': 736,
#  '673': 737,
#  'Near': 738,
#  'hardcourt': 739,
#  'dish': 740,
#  'owe': 741,
#  'Yang': 742,
#  "Dunkin'": 743,
#  'was': 744,
#  'Rhythm': 745,
#  'arctic': 746,
#  'Ranbir': 747,
#  'ropes': 748,
#  'Long-term': 749,
#  'comparatively': 750,
#  'Pristina': 751,
#  'Irwindale': 752,
#  'colleges': 753,
#  '500-meter': 754,
#  'TOURE': 755,
#  'Danai': 756,
#  'Munich': 757,
#  'nonexistent': 758,
#  'Incumbent': 759,
#  'Mohammadi': 760,
#  'theater': 761,
#  'accessible': 762,
#  'three-stage': 763,
#  'Sezibera': 764,
#  'disarms': 765,
#  'Azizullah': 766,
#  'afflicting': 767,
#  'setbacks': 768,
#  'Warsaw': 769,
#  'ludicrous': 770,
#  '64': 771,
#  'Express': 772,
#  'university': 773,
#  '106.5': 774,
#  'Yusgiantoro': 775,
#  'churches': 776,
#  "Shi'ite-led": 777,
#  'borrower': 778,
#  'authorization': 779,
#  'HIV-AIDS': 780,
#  'Kari': 781,
#  'Sylvester': 782,
#  'donkey': 783,
#  'full-length': 784,
#  'Rish': 785,
#  'Atiku': 786,
#  'Rachel': 787,
#  'scandal': 788,
#  'steadily': 789,
#  'speculators': 790,
#  'grudgingly': 791,
#  'tighter': 792,
#  'sperm': 793,
#  'viewing': 794,
#  'bit': 795,
#  'Gholamreza': 796,
#  'Vaile': 797,
#  'non-essential': 798,
#  'Eilat': 799,
#  'tit-for-tat': 800,
#  'Sulik': 801,
#  'weaponry': 802,
#  'Festus': 803,
#  'facilities': 804,
#  'bomber': 805,
#  '89': 806,
#  'innovation': 807,
#  'unpopular': 808,
#  'rest': 809,
#  'Accord': 810,
#  'dynamite': 811,
#  'enraged': 812,
#  'trademark': 813,
#  'clad': 814,
#  'reinforcement': 815,
#  'Albay': 816,
#  '7.00': 817,
#  'Benham': 818,
#  'sagging': 819,
#  'Opportunity': 820,
#  'reforestation': 821,
#  'overflowed': 822,
#  'usage': 823,
#  'higher-level': 824,
#  'postwar': 825,
#  'shape': 826,
#  'silo': 827,
#  'withdraw': 828,
#  'snorted': 829,
#  'compressed': 830,
#  'AT&T': 831,
#  'rekindled': 832,
#  'Janata': 833,
#  'AUNG': 834,
#  'thus': 835,
#  'Africa': 836,
#  'games': 837,
#  'Director-General': 838,
#  'Arab-dominated': 839,
#  'Millenium': 840,
#  'Tegucigalpa': 841,
#  'Rico': 842,
#  'avalanche': 843,
#  'rocket': 844,
#  'festivities': 845,
#  'bypass': 846,
#  'brazen': 847,
#  'Simmons': 848,
#  'Asia-Africa': 849,
#  'tomorrow': 850,
#  'Cholily': 851,
#  'Levinson': 852,
#  'measured': 853,
#  'Nursery': 854,
#  'counterkidnapping': 855,
#  'MUSEVENI': 856,
#  'Querrey': 857,
#  'tracking': 858,
#  'sunk': 859,
#  'sermons': 860,
#  'localities': 861,
#  'Jack': 862,
#  'rugby': 863,
#  'pro-Tibetan': 864,
#  'young': 865,
#  'IWF': 866,
#  'opium-producing': 867,
#  'pigs': 868,
#  'shoving': 869,
#  'Botanic': 870,
#  'student': 871,
#  'narrowed': 872,
#  'plurality': 873,
#  'insurgency-plagued': 874,
#  'Mahlangu': 875,
#  'Waaq': 876,
#  'demerits': 877,
#  'biodiversity': 878,
#  'Zhaoxing': 879,
#  'affiliations': 880,
#  'abductees': 881,
#  'glorious': 882,
#  'day': 883,
#  'Balad': 884,
#  'punishing': 885,
#  'investigators': 886,
#  'Quintana': 887,
#  'Blige': 888,
#  'Islamist-controlled': 889,
#  'Shurja': 890,
#  'El~Paso': 891,
#  'parents': 892,
#  'concludes': 893,
#  'naming': 894,
#  'Loach': 895,
#  'costly': 896,
#  'anchored': 897,
#  'thugs': 898,
#  'Kifaya': 899,
#  'logjams': 900,
#  'Treaties': 901,
#  'garage': 902,
#  'Minghe': 903,
#  'Alternative': 904,
#  'underlings': 905,
#  'propaganda': 906,
#  'Spectrum': 907,
#  'Blackwater': 908,
#  'Coppola': 909,
#  'relaxing': 910,
#  'Yousifiyah': 911,
#  'Mehmet': 912,
#  'Chesnot': 913,
#  'interagency': 914,
#  'Desire': 915,
#  'tuba': 916,
#  'introducing': 917,
#  'embarrassment': 918,
#  'Feyzabad': 919,
#  'glittering': 920,
#  'society': 921,
#  'outbreak': 922,
#  'Zeta': 923,
#  'Pacheco': 924,
#  'Alekseyeva': 925,
#  'Yemen-based': 926,
#  'H.W.': 927,
#  'High-powered': 928,
#  'Jokonya': 929,
#  'U.S.-born': 930,
#  'peeling': 931,
#  'neurosurgeon': 932,
#  'Jigme': 933,
#  'Beirut': 934,
#  'envoy': 935,
#  'skeptics': 936,
#  'cancel': 937,
#  'Shengyou': 938,
#  'hazelnuts': 939,
#  'bulldozers': 940,
#  'defeatism': 941,
#  'Iron': 942,
#  'India-U.S.': 943,
#  'Zaman': 944,
#  'futures': 945,
#  'eventual': 946,
#  'theaters': 947,
#  'grain': 948,
#  'Daniel': 949,
#  'downstream': 950,
#  '19-nation': 951,
#  'Guatemalan': 952,
#  'midnight-to-dawn': 953,
#  'Kerekou': 954,
#  'caffeine': 955,
#  'Dissel': 956,
#  'wildly': 957,
#  'IRAQ-POVERTY': 958,
#  'aggravate': 959,
#  'gadgets': 960,
#  'Nambiar': 961,
#  'urinary': 962,
#  '159th': 963,
#  'Amer': 964,
#  'implacable': 965,
#  'Souray': 966,
#  'low-ranking': 967,
#  'presidents': 968,
#  'rocky': 969,
#  '450': 970,
#  'transports': 971,
#  'Takeifa': 972,
#  'value': 973,
#  'U.N.-African': 974,
#  'fueled': 975,
#  'nine': 976,
#  'Marshal': 977,
#  'BP': 978,
#  'oil-drilling': 979,
#  'cartel': 980,
#  'ride': 981,
#  'portable': 982,
#  'al-Sherif': 983,
#  'Grindhouse': 984,
#  'Dhakla': 985,
#  'Choco': 986,
#  'Soviet-sponsored': 987,
#  'invasions': 988,
#  'al-Aalam': 989,
#  '54,000': 990,
#  'University': 991,
#  'Dunham': 992,
#  'Troubled': 993,
#  'al-Rai': 994,
#  'scruple': 995,
#  'nine-year': 996,
#  'Huaren': 997,
#  'eyes': 998,
#  'mutually': 999,
#  'Shelor': 1000,
#  ...}

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, 50, 50)              │       1,758,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d (SpatialDropout1D) │ (None, 50, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 50, 200)             │         120,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed (TimeDistributed)   │ (None, 50, 17)              │           3,417 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,883,117 (7.18 MB)
#  Trainable params: 1,883,117 (7.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
                            metrics=["accuracy"])

# %%
# !pip install livelossplot
# Out:
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.8.0)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.3.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (24.1)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (2024.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time
chkpt = ModelCheckpoint("model_weights.weights.h5",
                        monitor='val_loss',
                        verbose=1,
                        save_best_only=True,
                        save_weights_only=True,
                        mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy',
                               min_delta=0,
                               patience=1,
                               verbose=0,
                               mode='max',
                               baseline=None,
                               restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
        y=y_train,
            validation_data=(x_test,y_test),
                batch_size=32,
                    epochs=3,
                        callbacks=callbacks,
                            verbose=1
                            )
# Out:
# accuracy
# 	training         	 (min:    0.962, max:    0.989, cur:    0.989)
# 	validation       	 (min:    0.982, max:    0.986, cur:    0.986)
# Loss
# 	training         	 (min:    0.036, max:    0.154, cur:    0.036)
# 	validation       	 (min:    0.046, max:    0.062, cur:    0.046)
#
# Epoch 3: val_loss improved from 0.04973 to 0.04634, saving model to model_weights.weights.h5
# 1199/1199 ━━━━━━━━━━━━━━━━━━━━ 200s 136ms/step - accuracy: 0.9889 - loss: 0.0362 - val_accuracy: 0.9863 - val_loss: 0.0463
# CPU times: user 12min 3s, sys: 24.2 s, total: 12min 27s
# Wall time: 8min 55s

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.9860 - loss: 0.0471
# [0.04634317383170128, 0.9862658977508545]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# United         B-geo	B-geo
# States         I-geo	I-geo
# has            O	O
# 103            O	O
# nuclear        O	O
# power          O	O
# plants         O	O
# in             O	O
# 31             O	B-tim
# states         O	O
# .              O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
# showdown       O	O
